# %% [markdown]
# # Read Files

# %%
spark.sql('SHOW VOLUMES').show()

# %%
df=spark.read.format('csv')\
    .option('header',True)\
        .option('inferSchema',True)\
            .load('/Workspace/Users/ssudeep2006@gmail.com/big_mart_sales.csv')

# %% [markdown]
# # Read Table using the Spark Sql

# %%
spark.sql('SHOW tables').show()

# %%
df=spark.table('big_mart_sales')

# %%
df.show()

# %%
df.display()

# %%
df.printSchema()

# %% [markdown]
# # import pyspark

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# # Select

# %%
df.select(col('Item_Identifier'),col('Item_Outlet_Sales')).show()

# %% [markdown]
# # Alias function

# %%
df.select(col('Item_Identifier').alias('Item_id')).show()
