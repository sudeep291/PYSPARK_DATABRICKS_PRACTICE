# %%
df=spark.read.format('csv')\
    .option('inferSchema',True)\
        .option('header',True)\
            .load('/')

# %%
spark.sql('SHOW DATABASES').display()

# %%
spark.sql('SHOW tables').show()

# %%
df=spark.table('big_mart_sales')

# %%
df

# %%
df.show()

# %%
df.head(3)

# %%
df.select('Item_Identifier','Item_MRP','Outlet_Location_Type').display()

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df=spark.read.format('csv')\
    .option('inferSchema',True)\
        .option('header',True)\
            .load('/Volumes/workspace/default/my_files/')

# %%
df

# %%
df1=df.filter(col("Item_MRP")>1000)

# %%
df1.display()

# %%
df.select('Item_MRP').display()
